# %%
name = "alice"
age = 25
height = 8.9
is_student = True

# %%
print(name)
print(age)
# Out:
# alice
# 25

# %%
print(name, age, height, is_student)
# Out:
# alice 25 8.9 True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
name, age, height, is_student = "alice", 25, 7.6, True

# %%
#convert one variable dtype to another dtypes

# %%
num_str = "42"
num_int = int(num_str)
print(num_int)
# Out:
# 42

# %%
num_float = float(num_int)
num_float
# Out:
# 42.0

# %% [markdown]
# INPUT AND OUTPUT

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  JYOTI
# JYOTI

# %%
age = int(input("Enter your age: "))
print(age)
# Out:
# Enter your age:  22
# 22

# %%
name = input("Enter your name: ")
marks = int(input("Enter your marks: "))
print(f"{name} has sored {marks}")
# Out:
# Enter your name:  JYOTI
# Enter your marks:  80
# JYOTI has sored 80

# %%
#something i don't know

# %%
print(10 > 5)
print(10 == 5)
print(10 != 5)
# Out:
# True
# False
# True

# %%
age = 20
print(50 <= age <= 70)
# Out:
# False

# %%
x = True
y = False
print(x and y)
# Out:
# False

# %%
print(x or y)
# Out:
# True

# %%
income = 50000
credit_score = 70
eligibility = income > 30000 and credit_score > 700
print("Loan eligibility: ", eligibility)
# Out:
# Loan eligibility:  False

# %%
#list

# %%
numbers = [10, 20, 30, 50]
print(numbers)
# Out:
# [10, 20, 30, 50]

# %%
fruits = ["apple", "chiku", "lichi"]
fruits[0:3:2]
# Out:
# ['apple', 'lichi']

# %%
#add, remove, append lists

# %%
fruits.append("grapes")

# %%
fruits
# Out:
# ['apple', 'chiku', 'lichi', 'grapes']

# %%
fruits[1] = 'mango'

# %%
fruits
# Out:
# ['apple', 'mango', 'lichi', 'grapes']

# %%
fruits.remove("mango")

# %%
fruits
# Out:
# ['apple', 'lichi', 'grapes']
